# %% [markdown]
# # **My summary of paper devoted on image segmentation investigation**
#
# Among the big variety of techniques used for image segmentation over the years such as thresholding [1], relaxation [2], Markov Random Field based approaches [3], surface based segmentation [4] [5] , edge detection [6], methods based on fuzzy set theory [7] and others, neural network based approaches proved to be the most promising and successful. Convolutional neural networks (CNN) and fully convolutional networks (FCN), especially U-Net, are driving advances. CNN is a multi-layer neural network containing convolution, pooling, activation and fully connected layers. CNN for handwritten character recognition was first introduced in 1989 be LeCun and named LeNet [8], [9]. Since 2012, a few other networks based on CNN architecture and widely used for image classification and segmentation were proposed (AlexNet [10], ZFNet [11], GoogleNet [12], Residual Net [13], DenseNet [14], VGGNet [15]).  These classification networks can be adapted into FCN which are able to efficiently learn to make dense predictions for per-pixel tasks like semantic segmentation [16]. For example, U-net architecture achieves very good performance on very different biomedical segmentation applications [17].
#
# [1]	A. K. Jaln, “Segmentation of Document Images,” IEEE Trans. Pattern Anal. Mach. Intell., vol. I, no. 12, pp. 1322–1329, 1989.
# [2]	R. A., A. Rosenfeld, and A. Hummel, “Scene Labeling by Relaxation Operations,” Cybernetics, no. 6, pp. 420–433, 1976.
# [3]	A. K. Jain, “Advances in Mathematical Models for Image Processing,” Proc. IEEE, vol. 69, no. 5, pp. 502–528, 1981.
# [4]	P. J. Besl and R. C. Jain, “Segmentation Through Variable-Order Surface Fitting,” IEEE Trans. Pattern Anal. Mach. Intell., vol. 10, no. 2, pp. 167–192, 1988.
# [5]	N. Yokoya and M. D. Levine, “Range Image Segmentation Based on Differential Geometry: A Hybrid Approach,” IEEE Trans. Pattern Anal. Mach. Intell., vol. 11, no. 6, pp. 643–649, 1989.
# [6]	J. Canny, “A Computational Approach to Edge Detection,” IEEE Trans. Pattern Anal. Mach. Intell., no. 6, pp. 679–698, 1986.
# [7]	J. C. Bezdek, J. Keller, R. Krisnapuram, and N. R. Pal, Fuzzy models and algorithms for pattern recognition and image processing. 2005.
# [8]	Y. LeCun et al., “Backpropagation applied to digit recognition,” Neural computation, vol. 1, no. 4. pp. 541–551, 1989.
# [9]	Y. LeCun, L. Bottou, Y. Bengio, and P. Haffner, “Gradient-based learning applied to document recognition,” Proc. IEEE, vol. 86, no. 11, pp. 2278–2323, 1998.
# [10]	G. H. A Krizhevsky, I Sutskever, “ImageNet Classification with Deep Convolutional Neural Networks,” Adv. neural Inf. Process. Syst. Adv. neural Inf. Process. Syst., pp. 1097–1105, 2012.
# [11]	M. D. Zeiler and R. Fergus, “Visualizing and understanding convolutional networks,” Lect. Notes Comput. Sci. (including Subser. Lect. Notes Artif. Intell. Lect. Notes Bioinformatics), vol. 8689 LNCS, no. PART 1, pp. 818–833, 2014.
# [12]	A. R. C. Szegedy, W. Liu, Y. Jia, P. Sermanet, S. Reed, D. Anguelov, D. Erhan, V. Vanhoucke, “Going Deeper with Convolutions,” Proc. IEEE Conf. Comput. Vis. pattern Recognit., pp. 1–9, 2015.
# [13]	K. He, X. Zhang, S. Ren, and J. Sun, “Identity mappings in deep residual networks,” Lect. Notes Comput. Sci. (including Subser. Lect. Notes Artif. Intell. Lect. Notes Bioinformatics), vol. 9908 LNCS, pp. 630–645, 2016.
# [14]	K. Q. W. G. Huang, Z. Liu, L. Van Der Maaten, “Densely Connected Convolutional Networks,” Proc. IEEE Conf. Comput. Vis. pattern Recognit., pp. 4700–4708, 2017.
# [15]	K. Simonyan and A. Zisserman, “Very deep convolutional networks for large-scale image recognition,” 3rd Int. Conf. Learn. Represent. ICLR 2015 - Conf. Track Proc., pp. 1–14, 2015.
# [16]	Y. Zhang, Z. Qiu, T. Yao, D. Liu, and T. Mei, “Fully Convolutional Adaptation Networks for Semantic Segmentation,” Proc. IEEE Comput. Soc. Conf. Comput. Vis. Pattern Recognit., pp. 6810–6818, 2018.
# [17]	O. Ronneberger, P. Fischer, and T. Brox, “U-net: Convolutional networks for biomedical image segmentation,” Lect. Notes Comput. Sci. (including Subser. Lect. Notes Artif. Intell. Lect. Notes Bioinformatics), vol. 9351, pp. 234–241, 2015.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Импортитурем требуемые библиотеки

# %%
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from glob import glob
import cv2
import json
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks')

# %% [markdown]
# Проверим какая дериктория на данный момент и изменим на необходимую. Проверим изменение директории

# %%
os.getcwd()
os.chdir("/content/drive/My Drive/Colab Notebooks/cig_butts")
print(os.getcwd())
path = os.getcwd()
# Out:
# /content/drive/My Drive/Colab Notebooks/cig_butts

# %% [markdown]
# Посмотрим какие папки в папке train, используя f-string

# %%
os.listdir(f"{path}/train")
# Out:
# ['images', 'coco_annotations.json']

# %% [markdown]
# Получим список всех картинок в папке train, а также прочтём json file

# %%
images = os.listdir(f"{path}/train/images")
with open(f"{path}/train/coco_annotations.json", "r") as file_json:
    annotations = json.load(file_json)

# %% [markdown]
# Проверим структуру аннтотации к файлу. Выберем случайно номер изображения (196) и попробуем и попробуем понять какое выражение обращается к его сегментирующей маске

# %%
print(type(annotations))
print(len(annotations))
print(annotations.keys())
print(annotations["images"])
print(type(annotations["annotations"]))
print(len(annotations["annotations"]))
print(type(annotations["annotations"][196]))
print(annotations["annotations"][196].keys())
print(annotations["annotations"][196]['segmentation'][0])
#Получается, что имея НОМЕР изображения, обратится к его маске можно будет с помощью annotations["annotations"][НОМЕР]['segmentation'][0]
# Out:
# <class 'dict'>
# 5
# dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])
# [{'license': 0, 'file_name': '00000000.jpg', 'width': 512, 'height': 512, 'id': 0}, {'license': 0, 'file_name': '00000001.jpg', 'width': 512, 'height': 512, 'id': 1}, {'license': 0, 'file_name': '00000002.jpg', 'width': 512, 'height': 512, 'id': 2}, {'license': 0, 'file_name': '00000003.jpg', 'width': 512, 'height': 512, 'id': 3}, {'license': 0, 'file_name': '00000004.jpg', 'width': 512, 'height': 512, 'id': 4}, {'license': 0, 'file_name': '00000005.jpg', 'width': 512, 'height': 512, 'id': 5}, {'license': 0, 'file_name': '00000006.jpg', 'width': 512, 'height': 512, 'id': 6}, {'license': 0, 'file_name': '00000007.jpg', 'width': 512, 'height': 512, 'id': 7}, {'license': 0, 'file_name': '00000008.jpg', 'width': 512, 'height': 512, 'id': 8}, {'license': 0, 'file_name': '00000009.jpg', 'width': 512, 'height': 512, 'id': 9}, {'license': 0, 'file_name': '00000010.jpg', 'width': 512, 'height': 512, 'id': 10}, {'license': 0, 'file_name': '00000011.jpg', 'width': 512, 'height': 512, 'id': 11}, {'license': 0, 'file_name': '00000012.jpg', 'width': 512, 'height': 512, 'id': 12}, {'license': 0, 'file_name': '00000013.jpg', 'width': 512, 'height': 512, 'id': 13}, {'license': 0, 'file_name': '00000014.jpg', 'width': 512, 'height': 512, 'id': 14}, {'license': 0, 'file_name': '00000015.jpg', 'width': 512, 'height': 512, 'id': 15}, {'license': 0, 'file_name': '00000016.jpg', 'width': 512, 'height': 512, 'id': 16}, {'license': 0, 'file_name': '00000017.jpg', 'width': 512, 'height': 512, 'id': 17}, {'license': 0, 'file_name': '00000018.jpg', 'width': 512, 'height': 512, 'id': 18}, {'license': 0, 'file_name': '00000019.jpg', 'width': 512, 'height': 512, 'id': 19}, {'license': 0, 'file_name': '00000020.jpg', 'width': 512, 'height': 512, 'id': 20}, {'license': 0, 'file_name': '00000021.jpg', 'width': 512, 'height': 512, 'id': 21}, {'license': 0, 'file_name': '00000022.jpg', 'width': 512, 'height': 512, 'id': 22}, {'license': 0, 'file_name': '00000023.jpg', 'width': 512, 'height': 512, 'id': 23}, {'license': 0, 'file_name': '00000024.jpg', 'width': 512, 'height': 512, 'id': 24}, {'license': 0, 'file_name': '00000025.jpg', 'width': 512, 'height': 512, 'id': 25}, {'license': 0, 'file_name': '00000026.jpg', 'width': 512, 'height': 512, 'id': 26}, {'license': 0, 'file_name': '00000027.jpg', 'width': 512, 'height': 512, 'id': 27}, {'license': 0, 'file_name': '00000028.jpg', 'width': 512, 'height': 512, 'id': 28}, {'license': 0, 'file_name': '00000029.jpg', 'width': 512, 'height': 512, 'id': 29}, {'license': 0, 'file_name': '00000030.jpg', 'width': 512, 'height': 512, 'id': 30}, {'license': 0, 'file_name': '00000031.jpg', 'width': 512, 'height': 512, 'id': 31}, {'license': 0, 'file_name': '00000032.jpg', 'width': 512, 'height': 512, 'id': 32}, {'license': 0, 'file_name': '00000033.jpg', 'width': 512, 'height': 512, 'id': 33}, {'license': 0, 'file_name': '00000034.jpg', 'width': 512, 'height': 512, 'id': 34}, {'license': 0, 'file_name': '00000035.jpg', 'width': 512, 'height': 512, 'id': 35}, {'license': 0, 'file_name': '00000036.jpg', 'width': 512, 'height': 512, 'id': 36}, {'license': 0, 'file_name': '00000037.jpg', 'width': 512, 'height': 512, 'id': 37}, {'license': 0, 'file_name': '00000038.jpg', 'width': 512, 'height': 512, 'id': 38}, {'license': 0, 'file_name': '00000039.jpg', 'width': 512, 'height': 512, 'id': 39}, {'license': 0, 'file_name': '00000040.jpg', 'width': 512, 'height': 512, 'id': 40}, {'license': 0, 'file_name': '00000041.jpg', 'width': 512, 'height': 512, 'id': 41}, {'license': 0, 'file_name': '00000042.jpg', 'width': 512, 'height': 512, 'id': 42}, {'license': 0, 'file_name': '00000043.jpg', 'width': 512, 'height': 512, 'id': 43}, {'license': 0, 'file_name': '00000044.jpg', 'width': 512, 'height': 512, 'id': 44}, {'license': 0, 'file_name': '00000045.jpg', 'width': 512, 'height': 512, 'id': 45}, {'license': 0, 'file_name': '00000046.jpg', 'width': 512, 'height': 512, 'id': 46}, {'license': 0, 'file_name': '00000047.jpg', 'width': 512, 'he ...
# <class 'list'>
# 2000
# <class 'dict'>
# dict_keys(['segmentation', 'iscrowd', 'image_id', 'category_id', 'id', 'bbox', 'area'])
# [364.0, 292.5, 376.0, 290.5, 378.5, 288.0, 380.5, 261.0, 382.5, 253.0, 381.5, 207.0, 379.0, 205.5, 359.0, 206.5, 355.5, 214.0, 356.5, 250.0, 354.5, 270.0, 352.5, 274.0, 352.5, 288.0, 355.0, 290.5, 364.0, 292.5]

# %% [markdown]
# Убидимся что правильно можем обратится к ширине изображения для случайного номера 198

# %%
annotations["images"][198]["width"]
#Видим, что все верно
# Out:
# 512

# %% [markdown]
# Проверим, что в аннотациях везде сходится порядковый номер словаря в списке annotations["images"] и значение в данном словаре по ключу "id" (Вынести в докстринг)

# %%
for i in range(len(annotations["images"])):
  if i != annotations["images"][i]["id"]:
    print(i)
#Все верно

# %% [markdown]
# Получим ширину и высоту изображения для случайного номера

# %%
w, h = annotations["images"][196]['width'], annotations["images"][196]['height']
w, h
# Out:
# (512, 512)

# %% [markdown]
# Для последующей функции cv2.FillPoly создадим массив из нулей и приведем его к типу np.uint8 - (число от 0 до 255, т.к. это числа градации серого, или RGB каналов)

# %%
z = np.zeros((h,w)).astype(np.uint8)

# %% [markdown]
# Получим массив из маски для изображения 196, сделаем два столбца, приведем к типу int32, т.к. так требует функция fillPoly

# %%
q = np.array(annotations["annotations"][196]['segmentation'][0]).reshape(-1,2).astype(np.int32)
q
# Out:
# array([[364, 292],
#        [376, 290],
#        [378, 288],
#        ...,
#        [352, 288],
#        [355, 290],
#        [364, 292]], dtype=int32)

# %% [markdown]
# Применим к массиву нулей функцию fillPoly, которая "нарисует" 255 в списке многоугольников (в данном случае один многоугольник q, поэтому можно было и воспользоватся fillConvexPoly). Получим изображение из массива на выходе и посмотрим на него

# %%
#mask = np.zeros((4, 3))
#np.set_printoptions(threshold = 10)
cv2.fillPoly(z, [q], 255)
im = Image.fromarray(z)
im
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA88261B668>

# %% [markdown]
# Здесь были предприняты попытки разобраться, как именно "рисует" функция fillPoly в нулевой матрице. Не до конца разобрался, точно не просто по конечным кординатам, т.к. важен порядок списков в маске. Но и не идёт по порядку от координаты к координате, т.к. на сходились картинки...

# %%
#q = np.array([(2,2), (2,11),(11,2),(11,11)], 'int32')
#r = np.array([[0,0], [0,11], [3,11], [3,0]], 'int32')
#Важен порядок написания списков в массиве для дальнейшей маски
#z = np.zeros((512,512)).astype(np.uint8)
#np.set_printoptions(threshold = 1000000)
#cv2.fillPoly(z, [q, r], 1).T
#z
#im = Image.fromarray(z)
#im

# %% [markdown]
# Посмотрим как выглядит список имен изображений

# %%
images

# %% [markdown]
# Как выглядит имя конкретного изображения

# %%
images[2]
#Понятно. Всего восемь символов, и точка с расширением. Чтобы обратится к номеру, надо разбить строчку по символу (точка), получится список из строковых значений имени и расширения, обратиться к первому элементу списка и преобразовать его в int
# Out:
# '00000999.jpg'

# %% [markdown]
# Получим номер изображения случайного выбранного имени изображения

# %%
img_id = int(np.random.choice(images).split(".")[0])
print(img_id)
# Out:
# 1172

# %% [markdown]
# Проверим как получить из номера строку с восемью символами

# %%
f"{img_id:08}"
#Данной конструкцией
# Out:
# '00001172'

# %% [markdown]
# Откроем изображение, зная его номер

# %%
image = Image.open(f"{path}/train/images/{img_id:08}.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7FA430C48128>

# %% [markdown]
# Переведем его в массив

# %%
img = np.array(image)

# %% [markdown]
# Проверим форму массива

# %%
img.shape
#Все сходится, изображение 512 на 512 в трех каналах (RGB)
# Out:
# (512, 512, 3)

# %% [markdown]
# # Получение файла pred_val_template.csv

# %% [markdown]
# Скопируем функцию из библиотеки(в Google Colab мне не удалось загрузить модули. Я ознакомился с культурой написания кода, а именно разбиение программы на .py модули, но не удалось её реализовать, к сожалению)

# %%
def encode_rle(mask):
    """Returns encoded mask (run length) as a string.
    Parameters
    ----------
    mask : np.ndarray, 2d
        Mask that consists of 2 unique values: 0 - denotes background, 1 - denotes object.
    Returns
    -------
    str
        Encoded mask.
    Notes
    -----
    Mask should contains only 2 unique values, one of them must be 0, another value, that denotes
    object, could be different from 1 (for example 255).
    """
    pixels = mask.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]

    return ' '.join(str(x) for x in runs)

# %% [markdown]
# Создадим словарь из двух элементов, ключ первого - название необходимого столбца, значение по данному ключу - список из значений номеров изображений. Ключ второго - название второго столбца, значение - список из строк, каждая из которых кодирует изображение с номером в первом списке(по индексу это строки из второго списка)

# %% [markdown]
# Проверим на тесте такой подход

# %%
import pandas as pd
dict_for_csv = {}
dict_for_csv["img_id"] = [1, 2, 3, 4, 5]
dict_for_csv["rle"] = ["rle1", "rle2", "rle3", "rle4", "rle5"]
pd.DataFrame.from_dict(dict_for_csv)
# Out:
#    img_id   rle
# 0       1  rle1
# 1       2  rle2
# 2       3  rle3
# 3       4  rle4
# 4       5  rle5

# %% [markdown]
# Сделаем на необходимых данных

# %%
import pandas as pd    
dict_for_csv = {"img_id" : [], "rle_mask" : []}
images_valid = os.listdir("/content/drive/My Drive/Colab Notebooks/cig_butts/val/images")
with open("/content/drive/My Drive/Colab Notebooks/cig_butts/val/coco_annotations.json", "r") as file_json:
    annotations_valid = json.load(file_json)
for i in images_valid:
  img_id = int(i.split(".")[0])
  z = np.zeros((h,w)).astype(np.uint8)
  q = np.array(annotations_valid["annotations"][img_id]['segmentation'][0]).reshape(-1,2).astype(np.int32)
  mask = cv2.fillPoly(z, [q], 255).reshape(512, 512)
  dict_for_csv["img_id"].append(img_id)
  dict_for_csv["rle_mask"].append(encode_rle(mask))
DF = pd.DataFrame.from_dict(dict_for_csv)

# %%
DF
# Out:
#      img_id                                           rle_mask
# 0         0  73565 6 74076 9 74586 13 75094 19 75603 24 761...
# 1         2  47861 1 48371 4 48881 7 49392 9 49903 12 50415...
# 2         1  90785 7 91294 15 91804 18 92315 20 92826 22 93...
# 3         9  128725 2 129236 5 129747 8 130258 11 130274 5 ...
# 4         8  61032 3 61542 9 62053 13 62565 15 63076 18 635...
# ..      ...                                                ...
# 195     194  16730 7 17240 11 17750 16 18260 20 18771 23 19...
# 196     199  193769 10 194280 13 194791 16 195302 18 195814...
# 197     198  64595 3 65106 6 65616 9 66127 11 66638 13 6715...
# 198     197  175358 4 175869 11 175886 8 176380 35 176891 4...
# 199     196  104929 1 105439 4 105949 6 106459 9 106966 15 ...
#
# [200 rows x 2 columns]

# %% [markdown]
# Упорядочим по занчению первого столбца

# %%
DF1 = DF.sort_values(by = ["img_id"])
DF1
# Out:
#      img_id                                           rle_mask
# 0         0  73565 6 74076 9 74586 13 75094 19 75603 24 761...
# 2         1  90785 7 91294 15 91804 18 92315 20 92826 22 93...
# 1         2  47861 1 48371 4 48881 7 49392 9 49903 12 50415...
# 9         3  23796 9 24304 13 24811 18 25318 23 25826 28 26...
# 6         4  156992 1 157502 4 158013 6 158524 8 159034 10 ...
# ..      ...                                                ...
# 194     195  119466 12 119977 28 120488 38 120999 42 121510...
# 199     196  104929 1 105439 4 105949 6 106459 9 106966 15 ...
# 198     197  175358 4 175869 11 175886 8 176380 35 176891 4...
# 197     198  64595 3 65106 6 65616 9 66127 11 66638 13 6715...
# 196     199  193769 10 194280 13 194791 16 195302 18 195814...
#
# [200 rows x 2 columns]

# %% [markdown]
# Сбросим упорядоченные индексы, не сбросив остальное

# %%
Final_DF = DF1.reset_index(drop=True)

# %%
Final_DF
# Out:
#      img_id                                           rle_mask
# 0         0  73565 6 74076 9 74586 13 75094 19 75603 24 761...
# 1         1  90785 7 91294 15 91804 18 92315 20 92826 22 93...
# 2         2  47861 1 48371 4 48881 7 49392 9 49903 12 50415...
# 3         3  23796 9 24304 13 24811 18 25318 23 25826 28 26...
# 4         4  156992 1 157502 4 158013 6 158524 8 159034 10 ...
# ..      ...                                                ...
# 195     195  119466 12 119977 28 120488 38 120999 42 121510...
# 196     196  104929 1 105439 4 105949 6 106459 9 106966 15 ...
# 197     197  175358 4 175869 11 175886 8 176380 35 176891 4...
# 198     198  64595 3 65106 6 65616 9 66127 11 66638 13 6715...
# 199     199  193769 10 194280 13 194791 16 195302 18 195814...
#
# [200 rows x 2 columns]

# %% [markdown]
# Сохраним таблицу

# %%
Final_DF.to_csv("pred_val_template.csv", sep=',', encoding='utf-8')

# %% [markdown]
# # Получение данных для обучения сети

# %% [markdown]
# Создадим два массива для обучения [:,512,512,3] для изображений и [:,512,512,1] для маски. Для этого создадим пустые спики X_train, Y_train, далее пробегая по всем изображениям, будем получать массивы для самих изображений, их масок, приводить их к нужной размерности ([512,512,3], [512,512,1]) и добавлять в созданные ранее списки.

# %% [markdown]
# Проверим для одного изображения. При этом нормируемся на максимальное значение в массиве - 255.0

# %%
X1_train = []
X1_train.append(img)
X1_train.append(img)
X1_train = np.array(X1_train)
(X1_train/255.0).astype(np.float32)

# %% [markdown]
# Теперь сделаем в цикле для всех

# %%
X_train = []
Y_train = []
for i in images:
  img_id = int(i.split(".")[0])
  image = Image.open(f"{path}/train/images/{img_id:08}.jpg")
  img = np.array(image).astype(np.uint8)
  X_train.append(img)
  z = np.zeros((h,w)).astype(np.uint8)
  q = np.array(annotations["annotations"][img_id]['segmentation'][0]).reshape(-1,2).astype(np.int32)
  mask = cv2.fillPoly(z, [q], 255).reshape(512, 512, 1)
  Y_train.append(mask)

# %%
X_train_array = np.array(X_train)/255.0
print(X_train_array.shape)
Y_train_array = np.array(Y_train)/255.0
Y_train_array
X_train_array*255.0

# %% [markdown]
# Посмотри на двадцать третье изображение и тренировачном списке

# %%
Image.fromarray((X_train_array[22]*255).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA5AE916AC8>

# %% [markdown]
# Посмотрим на 23 маску в тренировочном списке.

# %%
Image.fromarray((Y_train_array[22]*255).reshape(512,512).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA8826FE6A0>

# %% [markdown]
# Все верно. Можно приступить к обучению сети на такой выборке.

# %% [markdown]
# # Обучение сети U-net

# %% [markdown]
# Библиотеки

# %%
import os
import sys
import random

import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# Строительные блоки сети U-Net, отвечающие за сопоставление массиву 3х3, пробегающему вдоль картинки, какое-то число, зависящее от значений в данном массиве и на картинке. Таким образом избавляемся от необходимости обучать нашу сеть на множестве тренировочоных сетов, где в одном, например, объекты в левом углу, в другом в правом, в третьем - перевернутые. Т.к. такой способ свертки выявляет градиенты в изображении, углы, линии, и т.д.
#
# Если без padding, то при такой свертке будет терятся (3-1) значение в каждом измерении

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    concat = keras.layers.Concatenate()([us, skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# %% [markdown]
# Сеть, делается светка до 32 на 32 и обратно

# %%
def UNet():
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((512, 512, 3))
    
    p0 = inputs
    c1, p1 = down_block(p0, f[0]) #512 -> 256
    c2, p2 = down_block(p1, f[1]) #256 -> 128
    c3, p3 = down_block(p2, f[2]) #128 -> 64
    c4, p4 = down_block(p3, f[3]) #64->32
    
    bn = bottleneck(p4, f[4])
    
    u1 = up_block(bn, c4, f[3]) #32 -> 64
    u2 = up_block(u1, c3, f[2]) #64 -> 128
    u3 = up_block(u2, c2, f[1]) #128 -> 256
    u4 = up_block(u3, c1, f[0]) #256 -> 512
    
    outputs = keras.layers.Conv2D(1, (1, 1), padding="same", activation="sigmoid")(u4)
    model = keras.models.Model(inputs, outputs)
    return model

# %% [markdown]
# Попытки приладить функции для метрики, данные в библиотеке для обучения сети

# %%
EPS = 1e-10

def test_metrics(true, pred):
  true = tf.convert_to_tensor(true)
  pred = tf.convert_to_tensor(pred)
  return(true - pred)

def dice(true, pred):
    """Dice score.
    Parameters
    ----------
    true : np.ndarray, 2d
         Ground truth mask that consists of 2 unique values: 0 - denotes background,
         1 - denotes object.
    pred : np.ndarray, 2d
         Predicted mask that consists of 2 unique values: 0 - denotes background,
         1 - denotes object.
    Returns
    -------
    float from 0 to 1
        Dice score. The greater the value of dice score the better.
    Notes
    -----
    Masks should contains only 2 unique values, one of them must be 0, another value, that denotes
    object, could be different from 1 (for example 255).
    """
    true = true.numpy().reshape(512,512)
    pred = pred.numpy().reshape(512,512)

    true = true.astype(bool)
    pred = pred.astype(bool)

    intersection = (true & pred).sum()
    im_sum = true.sum() + pred.sum()

    return 2.0 * intersection / (im_sum + EPS)


def get_dice(true, pred):
    """Mean dice score.
    Parameters
    ----------
    true : list[np.ndarray] or np.ndarray
         List of ground truth masks or one mask that consists of 2 unique values:
         0 - denotes background, 1 - denotes object.
    pred : list[np.ndarray] or np.ndarray
         List of predicted masks or one mask that consists of 2 unique values:
         0 - denotes background, 1 - denotes object.
    Returns
    -------
    float from 0 to 1
        Dice score or mean dice score in case then lists of masks are passed.
        The greater the value of dice score the better.
    Notes
    -----
    Masks should contains only 2 unique values, one of them must be 0, another value, that denotes
    object, could be different from 1 (for example 255).
    
    """
    true = true.numpy().reshape(512,512)
    pred = pred.numpy().reshape(512,512)
    assert type(true) == type(pred), "Types of true and pred should be the same."
    if isinstance(true, list):
        return np.mean([dice(t, p) for t, p in zip(true, pred)])
    elif isinstance(true, np.ndarray):
        return dice(true, pred)
    else:
        raise TypeError("Wrong type.")

# %% [markdown]
# Функция для метрики dice для keras

# %%
import keras.backend as K
def dice_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

# %% [markdown]
# Создание сети с нужной метрикой и функцией ошибки - binary_crossentropy

# %%
model = UNet()
model.compile(optimizer="adam", loss = "binary_crossentropy", metrics=[dice_coef])
model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 512, 512, 16) 448         input_12[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 512, 512, 16) 2320        conv2d_209[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_44 (MaxPooling2D) (None, 256, 256, 16) 0           conv2d_210[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 256, 256, 32) 4640        max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_211[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_45 (MaxPooling2D) (None, 128, 128, 32) 0           conv2d_212[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 128, 128, 64) 18496       max_pooling2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_213[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_46 (MaxPooling2D) (None, 64, 64, 64)   0           conv2d_214[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 64, 64, 128)  73856       max_pooling2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_215[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_47 (MaxPooling2D) (None, 32, 32, 128)  0           conv2d_216[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 32, 32, 256)  295168      max_pooling2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_217[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_44 (UpSampling2D) (None, 64, 64, 256)  0           conv2d_218[0][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 64, 64, 384)  0           up_sampling2d_44[0][0]
#                                                                  conv2d_216[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 64, 64, 128)  442496      concatenate_44[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_219[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_45 (UpSampling2D) (None, 128, 128, 128 0           conv2d_220[0][0]
# __________________________________________________________________________________________________
# concatenate_45 (Concatenate)    (None, 128, 128, 192 0           up_sampling2d_45[0][0]
#                                                                  conv2d_214[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 128, 128, 64) 110656      concatenate_45[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_221[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_46 (UpSampling2D) (None, 256, 256, 64) 0           conv2d_222[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 256, 256, 96) 0           up_sampling2d_46[0][0]
#                                                                  conv2d_212[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 256, 256, 32) 27680       concatenate_46[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_223[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_47 (UpSampling2D) (None, 512, 512, 32) 0           conv2d_224[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 512, 512, 48) 0           up_sampling2d_47[0][0]
#                                                                  conv2d_210[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 512, 512, 16) 6928        concatenate_47[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 512, 512, 16) 2320        conv2d_225[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 512, 512, 1)  17          conv2d_226[0][0]
# ==================================================================================================
# Total params: 1,962,625
# Trainable params: 1,962,625
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Обучение сети. Вместе правильного сета для валидации, данного в задании, использовались последние 10% для тренировочного, как наиболее быстрый вариант получения результатов и планирование правильного обучения в дальнейшем. По схожим соображениям и такое малое количество epochs)

# %%
model.fit(X_train_array, Y_train_array, validation_split = 0.1, batch_size = 10, epochs = 3, shuffle = True, verbose = 2)
# Out:
# Train on 450 samples, validate on 50 samples
# Epoch 1/3
# 450/450 - 12s - loss: 0.1090 - dice_coef: 0.0061 - val_loss: 0.0481 - val_dice_coef: 0.0113
# Epoch 2/3
# 450/450 - 11s - loss: 0.0478 - dice_coef: 0.0252 - val_loss: 0.0486 - val_dice_coef: 0.0308
# Epoch 3/3
# 450/450 - 11s - loss: 0.0419 - dice_coef: 0.0588 - val_loss: 0.0471 - val_dice_coef: 0.0676

# %% [markdown]
# # Получение данных на real_test

# %% [markdown]
# Делаем массив как для тренировачного сета, но без масок, только картинки

# %%
images_test = os.listdir("/content/drive/My Drive/Colab Notebooks/cig_butts/real_test")

# %%
X_test = []
for i in images_test:
  image = Image.open(f"/content/drive/My Drive/Colab Notebooks/cig_butts/real_test/{i}")
  img = np.array(image)
  X_test.append(img)

# %%
X_test_array = np.array(X_test)
X_test_array.shape
# Out:
# (10, 512, 512, 3)

# %% [markdown]
# Посмотрим на случайное изображение

# %%
Image.fromarray(X_test_array[8])
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA431D4CF98>

# %% [markdown]
# Получим данные от обученной сети

# %%
Y_test = model.predict((X_test_array/255.0), batch_size=10, verbose = 0)

# %% [markdown]
# Посмотрим на форму этих данных

# %%
Y_test.shape
# Out:
# (10, 512, 512, 1)

# %% [markdown]
# Посмотрим на сами данные

# %%
Image.fromarray((Y_test[0]*255.0).reshape(512,512).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA5AE922898>

# %% [markdown]
# Посмотрим на все данные, сохраним их и сделаем html файл

# %%
Image.fromarray((Y_test[1]*255.0).reshape(512,512).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA5AE922BE0>

# %%
Image.fromarray((Y_test[2]*255.0).reshape(512,512).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA5AE8B4748>

# %%
Image.fromarray((Y_test[3]*255.0).reshape(512,512).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA5AE81F470>

# %%
Image.fromarray((Y_test[4]*255.0).reshape(512,512).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA5AE81F198>

# %%
Image.fromarray((Y_test[5]*255.0).reshape(512,512).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA431E8A198>

# %%
Image.fromarray((Y_test[6]*255.0).reshape(512,512).astype(np.uint8))

# %%
Image.fromarray((Y_test[7]*255.0).reshape(512,512).astype(np.uint8))

# %%
Image.fromarray((Y_test[8]*255.0).reshape(512,512).astype(np.uint8))

# %%
Image.fromarray((Y_test[9]*255.0).reshape(512,512).astype(np.uint8))

# %%
Image.fromarray(X_test_array[0])

# %%
Image.fromarray(X_test_array[1])

# %%
Image.fromarray(X_test_array[2])

# %%
Image.fromarray(X_test_array[3])

# %%
Image.fromarray(X_test_array[4])

# %%
Image.fromarray(X_test_array[5])

# %%
Image.fromarray(X_test_array[6])

# %%
Image.fromarray(X_test_array[7])

# %%
Image.fromarray(X_test_array[8])

# %%
Image.fromarray(X_test_array[9])

# %% [markdown]
# Протестируем построение графиков функицей subplots

# %%
#ax1, ax2 = plt.subplots(1,2, figsize = (14,8))
#ax1.title("test")
